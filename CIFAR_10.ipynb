# %% [markdown]
# <a href="https://colab.research.google.com/github/hayounk/paper-reading/blob/main/CIFAR_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
cd /content/drive/MyDrive/cifar10_challenge-master
# Out:
# /content/drive/MyDrive/cifar10_challenge-master

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %% [markdown]
# # FGSM

# %%
# !python fetch_model.py natural
# Out:
# ...
# SHA256 hash: 6af2addfc5bc75e3b16b8654c907a8dfaebeffc600871115460063ade1cd1ee7
# Extracting model
# Extracted model in models/

# %%
# !python fgsm_attack.py
# Out:
# WARNING:tensorflow:From /content/drive/My Drive/cifar10_challenge-master/model.py:31: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/cifar10_challenge-master/model.py:33: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/image_ops_impl.py:1518: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# WARNING:tensorflow:From /content/drive/My Drive/cifar10_challenge-master/model.py:157: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
# ...

# %%
# !python run_attack_fgsm.py
# Out:
# WARNING:tensorflow:From /content/drive/My Drive/cifar10_challenge-master/model.py:31: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/cifar10_challenge-master/model.py:33: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/image_ops_impl.py:1518: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# WARNING:tensorflow:From /content/drive/My Drive/cifar10_challenge-master/model.py:157: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
# ...

# %% [markdown]
# plot을 얻기 위한 여행

# %%
# !python run_attack_fgsm.py
# Out:
# WARNING:tensorflow:From /content/drive/My Drive/cifar10_challenge-master/model.py:31: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/cifar10_challenge-master/model.py:33: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/image_ops_impl.py:1518: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# WARNING:tensorflow:From /content/drive/My Drive/cifar10_challenge-master/model.py:157: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
# ...

# %%
# !python eval.py
# Out:
# WARNING:tensorflow:From /content/drive/MyDrive/cifar10_challenge-master/model.py:31: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/cifar10_challenge-master/model.py:33: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/image_ops_impl.py:1518: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# WARNING:tensorflow:From /content/drive/MyDrive/cifar10_challenge-master/model.py:157: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
# ...

# %% [markdown]
# # PGD

# %%
# !python fetch_model.py adv_trained
# Out:
# ...
# SHA256 hash: 996384ac78ec749673e43cb823b9fb837a4da8d529ed2ef98e8d94053529fa5d
# Extracting model
# Extracted model in models/

# %%
# !python pgd_attack.py
# Out:
# WARNING:tensorflow:From /content/drive/My Drive/cifar10_challenge-master/model.py:31: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/cifar10_challenge-master/model.py:33: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/image_ops_impl.py:1518: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# WARNING:tensorflow:From /content/drive/My Drive/cifar10_challenge-master/model.py:157: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
# ...

# %%
# !python run_attack.py
# Out:
# WARNING:tensorflow:From /content/drive/My Drive/cifar10_challenge-master/model.py:31: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/cifar10_challenge-master/model.py:33: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/image_ops_impl.py:1518: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# WARNING:tensorflow:From /content/drive/My Drive/cifar10_challenge-master/model.py:157: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
# ...

# %%
# !python eval_pgd.py
# Out:
# WARNING:tensorflow:From /content/drive/My Drive/cifar10_challenge-master/model.py:31: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/cifar10_challenge-master/model.py:33: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/image_ops_impl.py:1518: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# WARNING:tensorflow:From /content/drive/My Drive/cifar10_challenge-master/model.py:157: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
# ...

# %% [markdown]
# # plot 을 얻어보자

# %%
import numpy as np

acc_fgsm = np.load('acc_fgsm.npy')
acc_pgd = np.load('acc_pgd.npy')

loss_fgsm = np.load('loss_fgsm.npy')
loss_natural = np.load('loss_natural.npy')

loss_pgd = np.load('loss_pgd.npy')
loss_pgd_nat = np.load('loss_pgdnatural.npy')

# %%
acc_fgsm
# Out:
# array([ 0.95,  1.84,  2.74,  3.64,  4.55,  5.46,  6.41,  7.32,  8.23,
#         9.13, 10.04, 10.95, 11.91, 12.83, 13.77, 14.73, 15.65, 16.52,
#        17.43, 18.31, 19.2 , 20.13, 21.03, 21.99, 22.92, 23.8 , 24.73,
#        25.67, 26.59, 27.48, 28.41, 29.31, 30.23, 31.13, 32.02, 32.92,
#        33.85, 34.75, 35.66, 36.6 , 37.53, 38.44, 39.39, 40.31, 41.24,
#        42.14, 43.06, 43.94, 44.88, 45.79, 46.72, 47.59, 48.49, 49.42,
#        50.33, 51.24, 52.14, 53.04, 53.91, 54.84, 55.74, 56.63, 57.56,
#        58.51, 59.45, 60.32, 61.22, 62.07, 62.96, 63.86, 64.78, 65.69,
#        66.63, 67.56, 68.48, 69.41, 70.3 , 71.23, 72.13, 73.03, 73.98,
#        74.9 , 75.83, 76.77, 77.67, 78.58, 79.53, 80.39, 81.34, 82.27,
#        83.18, 84.12, 85.02, 85.92, 86.87, 87.79, 88.72, 89.64, 90.56,
#        91.54])

# %%
acc_fgsm
# Out:
# array([ 0.95,  1.84,  2.74,  3.64,  4.55,  5.46,  6.41,  7.32,  8.23,
#         9.13, 10.04, 10.95, 11.91, 12.83, 13.77, 14.73, 15.65, 16.52,
#        17.43, 18.31, 19.2 , 20.13, 21.03, 21.99, 22.92, 23.8 , 24.73,
#        25.67, 26.59, 27.48, 28.41, 29.31, 30.23, 31.13, 32.02, 32.92,
#        33.85, 34.75, 35.66, 36.6 , 37.53, 38.44, 39.39, 40.31, 41.24,
#        42.14, 43.06, 43.94, 44.88, 45.79, 46.72, 47.59, 48.49, 49.42,
#        50.33, 51.24, 52.14, 53.04, 53.91, 54.84, 55.74, 56.63, 57.56,
#        58.51, 59.45, 60.32, 61.22, 62.07, 62.96, 63.86, 64.78, 65.69,
#        66.63, 67.56, 68.48, 69.41, 70.3 , 71.23, 72.13, 73.03, 73.98,
#        18.8298288 , 19.31696632, 19.73979572, 20.21834019, 20.69190552,
#        21.26195976, 21.78608528, 22.20866119, 22.54079113, 23.02343029,
#        23.38770588, 23.98562084, 24.35180691, 24.75745346, 25.38705753,
#        25.79098232, 26.33488422, 26.69928875, 27.28742249, 27.75414253,
#        28.33016148, 28.85473175, 29.11481083, 29.28138977, 29.76584648,
# ...

# %%
loss_pgd
# Out:
# array([ 0.40746616,  0.81564342,  1.43817436,  1.90503189,  2.36969173,
#         2.66396444,  3.12650015,  3.62234686,  3.95225946,  4.3583082 ,
#         4.85525576,  5.39092676,  5.77066839,  6.23587408,  6.45071486,
#         6.78946558,  7.24515009,  7.8418107 ,  8.54034349,  9.13141069,
#         9.6574592 , 10.16255781, 10.61956553, 10.97795805, 11.50807226,
#        12.21076513, 12.48950726, 12.79390797, 13.16661285, 13.6075943 ,
#        14.15360989, 14.60293957, 15.02277027, 15.46323925, 16.14117611,
#        16.51548973, 17.07436535, 17.55281067, 17.90236965, 18.34742119,
#        18.8298288 , 19.31696632, 19.73979572, 20.21834019, 20.69190552,
#        21.26195976, 21.78608528, 22.20866119, 22.54079113, 23.02343029,
#        23.38770588, 23.98562084, 24.35180691, 24.75745346, 25.38705753,
#        25.79098232, 26.33488422, 26.69928875, 27.28742249, 27.75414253,
#        28.33016148, 28.85473175, 29.11481083, 29.28138977, 29.76584648,
# ...

# %%
loss_pgd_nat
# Out:
# array([ 0.40478794,  0.80284115,  1.41965641,  1.88847393,  2.35633343,
#         2.63701233,  3.10789242,  3.60405506,  3.94111118,  4.34799244,
#         4.84021179,  5.37292404,  5.74609863,  6.20829578,  6.413482  ,
#         6.75372591,  7.20454062,  7.79549921,  8.48250429,  9.0692058 ,
#         9.58625406, 10.0911759 , 10.54894838, 10.91862776, 11.44559599,
#        12.14344229, 12.42533134, 12.73697435, 13.09952005, 13.53578451,
#        14.08134432, 14.52119005, 14.94660685, 15.39093985, 16.07109854,
#        16.42981386, 16.98941252, 17.47094603, 17.81735533, 18.25331495,
#        18.73141977, 19.21135996, 19.63128656, 20.11113626, 20.58029531,
#        21.16191744, 21.67651709, 22.09996374, 22.42031382, 22.89627974,
#        23.24399832, 23.82474009, 24.18950636, 24.57453875, 25.20261381,
#        25.59922125, 26.13300581, 26.4955604 , 27.06401419, 27.53346254,
#        28.10235563, 28.62953299, 28.87693016, 29.03580748, 29.50985823,
# ...

# %%
import matplotlib.pyplot as plt

epochs = range(0, 100)

plt.plot(epochs, acc_fgsm, label='FGSM attack')
plt.plot(epochs, acc_pgd, label='PGD attack')
plt.xlabel('Iterations')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
len(loss_fgsm)
# Out:
# 100

# %%
epochs = range(0, 100)

plt.plot(epochs, loss_fgsm, label='FGSM attack')
plt.plot(epochs, loss_pgd, label='PGD attack')
# plt.plot(epochs, loss_natural, label = 'Natural')
# plt.plot(epochs, loss_pgd_nat, label = 'PGDNatural')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.plot(epochs, loss_fgsm, label='FGSM attack')
plt.plot(epochs, loss_pgd, label='PGD attack')
plt.plot(epochs, loss_natural, label = 'Natural')
plt.xlabel('batch_size')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
learning = np.load('learning.npy')

len(learning)
# Out:
# 100

# %%
plt.plot(epochs, learning)

# %%
fgsm = np.load('fgsmattack.npy')

fgsm
# Out:
# array([[[[164.77879074, 112.94243395,  55.36426561],
#          [160.31068612, 117.15489521,  48.05532088],
#          [166.95214606, 122.31408302,  46.08351199],
#          ...,
#          [135.32004488,  95.8591735 ,  36.5732154 ],
#          [122.76754687,  97.88264238,  39.7829007 ],
#          [118.73184994,  82.25295397,  39.25446476]],
#
#         [[144.34079546, 114.72293795,  56.29311658],
#          [157.10289828, 103.04345662,  34.57406913],
#          [159.81088265, 117.19255955,  38.0036046 ],
#          ...,
#          [128.88355103,  94.55417312,  25.9916239 ],
#          [126.07538327,  89.39360687,  30.31070562],
#          [116.69468698,  91.79726006,  33.06117388]],
#
#         [[156.96741281, 104.65611577,  46.44767844],
#          [152.30562155, 109.91061838,  37.24373303],
#          [162.91423996, 111.53842225,  43.01210871],
#          ...,
#          [139.77815842,  97.61159241,  32.8384238 ],
#          [123.09084783,  98.42816817,  36.79993085],
# ...

# %%
import matplotlib.pyplot as plt

epochs = range(0, 100)

plt.plot(epochs, loss_fgsm, label='FGSM attack')
# plt.plot(epochs, loss_pgd, label='PGD attack')
plt.plot(epochs, loss_natural, label = 'Natural')
# plt.plot(epochs, loss_pgd_nat, label = 'PGDNatural')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.plot(loss_fgsm, learn, label='FGSM attack')
# plt.plot(epochs, loss_pgd, label='PGD attack')
plt.plot(loss_natural, learn, label = 'Natural')
# plt.plot(epochs, loss_pgd_nat, label = 'PGDNatural')
plt.xlabel('Loss')
plt.ylabel('Epochs')
plt.legend()
plt.show()

# %%
fgsm_attack = np.load('fgsmattack.npy')

x = fgsm_attack[:, 0]
y = fgsm_attack[:, 1]
z = fgsm_attack[:, 2]

x = 

print(x.shape)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-71be04e93a1d> in <module>()
#       5 z = fgsm_attack[:, 2]
#       6
# ----> 7 x = x.reshape(10000, )
#       8
#       9 print(x.shape)
#
# ValueError: cannot reshape array of size 960000 into shape (10000,)

# %%
import matplotlib.pyplot as plt

iteration = range(0, 960000)

plt.plot(iteration, x, label='FGSM attack')
# plt.plot(iteration, y, label='PGD attack')
# plt.plot(iteration, z, label = 'Natural')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
len(iteration)
# Out:
# 960000

# %%
y
# Out:
# array([148.80684053, 111.69826273,  57.22933985, ..., 114.73009211,
#        125.31806642, 134.20200449])

# %%
z
# Out:
# array([158.94796723, 115.37767594,  52.2579407 , ...,  67.15043907,
#         66.29770802,  71.74626097])

# %%
x - y
# Out:
# array([ 6.06717979, -3.745171  , -7.12253909, ..., 82.5697062 ,
#        89.68197506, 88.83982041])

# %%
# !python fetch_model.py natural
# Out:
# ...
# SHA256 hash: 6af2addfc5bc75e3b16b8654c907a8dfaebeffc600871115460063ade1cd1ee7
# Extracting model
# Extracted model in models/

# %%
# !python run_attack_fgsm.py
# Out:
# WARNING:tensorflow:From /content/drive/MyDrive/cifar10_challenge-master/model.py:31: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/cifar10_challenge-master/model.py:33: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/image_ops_impl.py:1518: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# WARNING:tensorflow:From /content/drive/MyDrive/cifar10_challenge-master/model.py:157: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
# ...

# %%
# !python eval.py
# Out:
# WARNING:tensorflow:From /content/drive/My Drive/cifar10_challenge-master/model.py:31: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/cifar10_challenge-master/model.py:33: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/image_ops_impl.py:1518: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# WARNING:tensorflow:From /content/drive/My Drive/cifar10_challenge-master/model.py:157: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
# ...

# %% [markdown]
# # 실험

# %%
# !python fetch_model.py natural
# Out:
# ...
# SHA256 hash: 6af2addfc5bc75e3b16b8654c907a8dfaebeffc600871115460063ade1cd1ee7
# Extracting model
# Extracted model in models/

# %%
# !python fgsm_attack_modi.py
# Out:
# WARNING:tensorflow:From /content/drive/My Drive/cifar10_challenge-master/model.py:31: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/cifar10_challenge-master/model.py:33: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/image_ops_impl.py:1518: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# WARNING:tensorflow:From /content/drive/My Drive/cifar10_challenge-master/model.py:157: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
# ...

# %%
# !python run_attack_fgsm2.py
# Out:
# WARNING:tensorflow:From /content/drive/My Drive/cifar10_challenge-master/model.py:31: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/cifar10_challenge-master/model.py:33: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/image_ops_impl.py:1518: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# WARNING:tensorflow:From /content/drive/My Drive/cifar10_challenge-master/model.py:157: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
# ...

# %%
# !python eval_fgsm2.py
# Out:
# WARNING:tensorflow:From /content/drive/My Drive/cifar10_challenge-master/model.py:31: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/cifar10_challenge-master/model.py:33: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/image_ops_impl.py:1518: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# WARNING:tensorflow:From /content/drive/My Drive/cifar10_challenge-master/model.py:157: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
# ...
